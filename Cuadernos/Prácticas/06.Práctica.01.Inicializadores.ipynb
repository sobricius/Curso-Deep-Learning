# %% [markdown]
# # Práctica de Inicializadores

# %% [markdown]
# ### Importaciones

# %%
import keras
import matplotlib.pyplot as plt
import numpy as np
import tensorflow
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical, normalize

# %% [markdown]
# ### Lectura de la información: dataset MNIST de Keras

# %%
# 1.- Lectura en conjuntos de enrenamiento y test con keras.datasets.mnist.load_data()

# %% [markdown]
# ### Preparación de los datos

# %%
# 2.- Conversión de la columna objetivo en categórica (usar keras.utils.to_categorical)



# 3.- Normalización de las entradas usando keras.utils.normalize



# 4.-Mostrar las dimensiones de cada uno de los cuatro datasets (arrays)
# Out:
# (60000, 28, 28)
# (60000, 10)
# (10000, 28, 28)
# (10000, 10)

# %% [markdown]
# ### Creación y compilación del modelo:

# %%
# 5.- Función que crea y compila el modelo y recibe como argumento el nombre del inicializador
#     Modelo: capa de aplanamiento, 5 capas densas de 100 unidades (activación ReLU) y capa de salida
#             de 10 unidades y activación softmax

def crea_modelo(inicializador):

  # crea modelo
  modelo = 

  # añade las capas 
  modelo.add(...)
  

  # 6.- Compilación del modelo con adam como optimizador, exactitud como métrica y 
  #     la función de pérdidas que corresponda
  modelo.compile(...)

  
  return modelo

# %% [markdown]
# ### Bucle de entrenamiento

# %%
# 7.- Hacer un entrenamiento con cada uno de los siguientes inicializadores:
#     'glorot_normal', 'glorot_uniform', 'he_normal', 'he_uniform', 'lecun_normal' y 'lecun_uniform'.
#
#     Se deben guardar las historias devueltas por los entrenamiento en una lista para poder visualizarlas
#     en la misma gráfica.
inicializadores = ['glorot_normal', 'glorot_uniform', 'he_normal', 'he_uniform', 'lecun_normal','lecun_uniform']
# Out:
# --------------------
#  glorot_normal
# --------------------
# Epoch 1/40
# 469/469 [==============================] - 3s 4ms/step - loss: 0.7307 - accuracy: 0.7714 - val_loss: 0.1715 - val_accuracy: 0.9482
# Epoch 2/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1532 - accuracy: 0.9528 - val_loss: 0.1330 - val_accuracy: 0.9606
# Epoch 3/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1042 - accuracy: 0.9678 - val_loss: 0.1183 - val_accuracy: 0.9662
# Epoch 4/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0736 - accuracy: 0.9768 - val_loss: 0.1026 - val_accuracy: 0.9677
# Epoch 5/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0578 - accuracy: 0.9816 - val_loss: 0.1139 - val_accuracy: 0.9653
# Epoch 6/40
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0497 - accuracy: 0.9845 - val_loss: 0.1037 - val_accuracy: 0.9685
# Epoch 7/40
# ...

# %% [markdown]
# ### Gráfica de evolución de la exactitud en los entrenamientos

# %%
# 8.- Mostrar en una misma gráfica la evolución de la exactitud de los entrenamientos.
