# %% [markdown]
# # Práctica de Clasificiación Binaria
#
# Supervivientes del Titanic: [Descripción del dataset](https://www.kaggle.com/c/titanic/data)

# %% [markdown]
# ### Interpretación de las columnas (el resto o no interesan o su significado es obvio):
# - SibSp: número de hermanos + cónyuges a bordo.
# - Parch: número de padres o hijos a bordo Titanic
# - Pclass: clase -> 1 (primera), 2 (segunda), 3 (tercera)
# - Fare: precio del pasaje
# - Embarked: Puerto de embarque -> C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# ### Montar Google Drive

# %% [markdown]
# ### Importaciones

# %%
import numpy
import pandas as pd
from sklearn import preprocessing
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
import tensorflow.keras.utils
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Carga del dataset: Titanic.csv

# %%
# 1.- Carga del dataset en un DataFrame de Pandas


# 2.- Mostrarlas cinco primeras filas del dataframe
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Preparación de los datos

# %% [markdown]
# #### Selección de las columnas de interés:

# %%
# 3.- Modificar el DataFrame para que que solo contenga las columnas:
#       'Survived','Name','Pclass','Sex','Age','SibSp','parch','Fare' y 'Embarked'.
#     Confirmar los cambios mostrando de nuevo las cinco primeras filas.
# Out:
#    Survived                                               Name  Pclass  \
# 0         0                            Braund, Mr. Owen Harris       3
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2         1                             Heikkinen, Miss. Laina       3
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4         0                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch     Fare Embarked
# 0    male  22.0      1      0   7.2500        S
# 1  female  38.0      1      0  71.2833        C
# 2  female  26.0      0      0   7.9250        S
# 3  female  35.0      1      0  53.1000        S
# 4    male  35.0      0      0   8.0500        S

# %% [markdown]
# #### Aleatorización del DataFrame y preparación de los datos

# %%
# 4.- Usar el método 'sample' para aleatorizar el DataFrame

# 5.- Eliminar la columna del nombre ('Name')

# 6.- Reemplazar los datos perdidos de la columna edad ('Age') con su promedio

# 7.- Reemplazar nos datos perdidos de la columna pasaje ('Fare') con su promedio

# 8.- Convertir los datos de la columna sexo ('Sex') en 0 para mujer ('female') y 1 para hombre ('male')
#     Usar la función map de Pandas.

# 9.- Reemplazar los datos perdidos de la columna 'Embarked' por 'S'

# 10.- Usando la función map, reemplazar los valores de la columna 'Embarked' del siguiente modo:
#             'C' -> 0,  'Q' -> 1,  'S' -> 2
#             Los valores finales deben ser de tipo entero (int)

# 11.- Extraer a un array de numpy los valores de todas las columnas excepto la de objetivo ('Survived')

# 12.- Extraer en un array de numpy la columna objetivo ('Survived')

# %% [markdown]
# #### Generación de los conjuntos de entrenamiento y test

# %%
# 13.- Entrenamiento: 80% - Test: 20%

# %% [markdown]
# ### Construcción y compilación de la red

# %%
# 14.- Modelo:
#        - Tres capas densas (activación ReLU): 64,32 y 16 unidades
#        - Capa de salida con activación sigmoide



# 15.- Compilación con los siguientes parámetros:
#        - Optimizador: Adam
#        - Métrica: Exactitud (accuracy)
#        - Función de pérdidas: deducirla

# %% [markdown]
# ### Entrenamiento de la red

# %%
# 16.- Entrenar con un 20% de datos para validación, 100 epochs y un tamaño de batch de 128 muestras.
# Out:
# Epoch 1/100
# 5/5 - 1s - loss: 0.8615 - accuracy: 0.6397 - val_loss: 0.7443 - val_accuracy: 0.6364 - 808ms/epoch - 162ms/step
# Epoch 2/100
# 5/5 - 0s - loss: 0.8012 - accuracy: 0.6204 - val_loss: 0.6493 - val_accuracy: 0.7133 - 42ms/epoch - 8ms/step
# Epoch 3/100
# 5/5 - 0s - loss:
ms/step
# Epoch 51/100
# 5/5 - 0s - loss: 0.5046 - accuracy: 0.7206 - val_loss: 0.4629 - val_accuracy: 0.7832 - 36ms/epoch - 7ms/step
# Epoch 52/100
# 5/5 - 0s - loss: 0.5090 - accuracy: 0.7434 - val_loss: 0.4547 - val_accuracy: 0.7692 - 36ms/epoch - 7ms/step
# Epoch 53/100
# 5/5 - 0s - loss: 0.5046 - accuracy: 0.7329 - val_loss: 0.4474 - val_accuracy: 0.7902 - 40ms/epoch - 8ms/step
# Epoch 54/100
# 5/5 - 0s - loss: 0.5041 - accuracy: 0.7434 - val_loss: 0.4544 - val_accuracy: 0.7832 - 42ms/epoch - 8ms/step
# Epoch 55/100
# 5/5 - 0s - loss: 0.4993 - accuracy: 0.7540 - val_loss: 0.4483 - val_accuracy: 0.7832 - 38ms/epoch - 8ms/step
# Epoch 56/100
# 5/5 - 0s - loss: 0.5003 - accuracy: 0.7487 - val_loss: 0.4484 - val_accuracy: 0.7762 - 37ms/epoch - 7ms/step
# Epoch 57/100
# 5/5 - 0s - loss: 0.4973 - accuracy: 0.7329 - val_loss: 0.4437 - val_accuracy: 0.7832 - 37ms/epoch - 7ms/step
# Epoch 58/100
# 5/5 - 0s - loss: 0.4901 - accuracy: 0.7645 - val_loss: 0.4436 - val_accuracy: 0.7902 - 41ms/epoch - 8ms/step
# Epoch 59/100
# 5/5 - 0s - loss: 0.4895 - accuracy: 0.7487 - val_loss: 0.4407 - val_accuracy: 0.7762 - 39ms/epoch - 8ms/step
# Epoch 60/100
# 5/5 - 0s - loss: 0.4868 - accuracy: 0.7540 - val_loss: 0.4420 - val_accuracy: 0.7902 - 37ms/epoch - 7ms/step
# Epoch 61/100
# 5/5 - 0s - loss: 0.4884 - accuracy: 0.7891 - val_loss: 0.4390 - val_accuracy: 0.8042 - 37ms/epoch - 7ms/step
# Epoch 62/100
# 5/5 - 0s - loss: 0.4827 - accuracy: 0.7627 - val_loss: 0.4388 - val_accuracy: 0.7762 - 36ms/epoch - 7ms/step
# Epoch 63/100
# 5/5 - 0s - loss: 0.4846 - accuracy: 0.7434 - val_loss: 0.4388 - val_accuracy: 0.8252 - 40ms/epoch - 8ms/step
# Epoch 64/100
# 5/5 - 0s - loss: 0.4867 - accuracy: 0.7803 - val_loss: 0.4398 - val_accuracy: 0.8112 - 45ms/epoch - 9ms/step
# Epoch 65/100
# 5/5 - 0s - loss: 0.4830 - accuracy: 0.8014 - val_loss: 0.4392 - val_accuracy: 0.7832 - 37ms/epoch - 7ms/step
# Epoch 66/100
# 5/5 - 0s - loss: 0.4873 - accuracy: 0.7575 - val_loss: 0.4404 - val_accuracy: 0.7762 - 37ms/epoch - 7ms/step
# Epoch 67/100
# 5/5 - 0s - loss: 0.4792 - accuracy: 0.7909 - val_loss: 0.4452 - val_accuracy: 0.8462 - 42ms/epoch - 8ms/step
# Epoch 68/100
# 5/5 - 0s - loss: 0.4802 - accuracy: 0.7961 - val_loss: 0.4337 - val_accuracy: 0.7832 - 36ms/epoch - 7ms/step
# Epoch 69/100
# 5/5 - 0s - loss: 0.4760 - accuracy: 0.7733 - val_loss: 0.4309 - val_accuracy: 0.8042 - 40ms/epoch - 8ms/step
# Epoch 70/100
# 5/5 - 0s - loss: 0.4711 - accuracy: 0.7821 - val_loss: 0.4278 - val_accuracy: 0.8322 - 38ms/epoch - 8ms/step
# Epoch 71/100
# 5/5 - 0s - loss: 0.4699 - accuracy: 0.7996 - val_loss: 0.4293 - val_accuracy: 0.8112 - 38ms/epoch - 8ms/step
# Epoch 72/100
# 5/5 - 0s - loss: 0.4651 - accuracy: 0.8032 - val_loss: 0.4211 - val_accuracy: 0.8392 - 44ms/epoch - 9ms/step
# Epoch 73/100
# 5/5 - 0s - loss: 0.4665 - accuracy: 0.7856 - val_loss: 0.4171 - val_accuracy: 0.8462 - 35ms/epoch - 7ms/step
# Epoch 74/100
# 5/5 - 0s - loss: 0.4642 - accuracy: 0.7873 - val_loss: 0.4342 - val_accuracy: 0.7832 - 36ms/epoch - 7ms/step
# Epoch 75/100
# 5/5 - 0s - loss: 0.4693 - accuracy: 0.7996 - val_loss: 0.4226 - val_accuracy: 0.8392 - 35ms/epoch - 7ms/step
# Epoch 76/100
# 5/5 - 0s - loss: 0.4671 - accuracy: 0.7961 - val_loss: 0.4261 - val_accuracy: 0.7972 - 37ms/epoch - 7ms/step
# Epoch 77/100
# 5/5 - 0s - loss: 0.4774 - accuracy: 0.7733 - val_loss: 0.4311 - val_accuracy: 0.7902 - 42ms/epoch - 8ms/step
# Epoch 78/100
# 5/5 - 0s - loss: 0.4751 - accuracy: 0.7944 - val_loss: 0.4389 - val_accuracy: 0.8322 - 37ms/epoch - 7ms/step
# Epoch 79/100
# 5/5 - 0s - loss: 0.4882 - accuracy: 0.7838 - val_loss: 0.4344 - val_accuracy: 0.7483 - 37ms/epoch - 7ms/step
# Epoch 80/100
# 5/5 - 0s - loss: 0.5001 - accuracy: 0.7381 - val_loss: 0.4417 - val_accuracy: 0.8392 - 36ms/epoch - 7ms/step
# Epoch 81/100
# 5/5 - 0s - loss: 0.5108 - accuracy: 0.7592 - val_loss: 0.4352 - val_accuracy: 0.8112 - 41ms/epoch - 8ms/step
# Epoch 82/100
# 5/5 - 0s - loss: 0.4882 - accuracy: 0.7733 - val_loss: 0.4351 - val_accuracy: 0.7832 - 45ms/epoch - 9ms/step
# Epoch 83/100
# 5/5 - 0s - loss: 0.4819 - accuracy: 0.7750 - val_loss: 0.4450 - val_accuracy: 0.8252 - 39ms/epoch - 8ms/step
# Epoch 84/100
# 5/5 - 0s - loss: 0.4779 - accuracy: 0.7873 - val_loss: 0.4303 - val_accuracy: 0.7692 - 36ms/epoch - 7ms/step
# Epoch 85/100
# 5/5 - 0s - loss: 0.4501 - accuracy: 0.8014 - val_loss: 0.4271 - val_accuracy: 0.8462 - 35ms/epoch - 7ms/step
# Epoch 86/100
# 5/5 - 0s - loss: 0.4646 - accuracy: 0.7821 - val_loss: 0.4326 - val_accuracy: 0.7902 - 36ms/epoch - 7ms/step
# Epoch 87/100
# 5/5 - 0s - loss: 0.4572 - accuracy: 0.8102 - val_loss: 0.4204 - val_accuracy: 0.8252 - 44ms/epoch - 9ms/step
# Epoch 88/100
# 5/5 - 0s - loss: 0.4581 - accuracy: 0.7996 - val_loss: 0.4218 - val_accuracy: 0.8252 - 48ms/epoch - 10ms/step
# Epoch 89/100
# 5/5 - 0s - loss: 0.4501 - accuracy: 0.8137 - val_loss: 0.4244 - val_accuracy: 0.8322 - 38ms/epoch - 8ms/step
# Epoch 90/100
# 5/5 - 0s - loss: 0.4474 - accuracy: 0.7996 - val_loss: 0.4130 - val_accuracy: 0.8322 - 38ms/epoch - 8ms/step
# Epoch 91/100
# 5/5 - 0s - loss: 0.4460 - accuracy: 0.7996 - val_loss: 0.4125 - val_accuracy: 0.8182 - 39ms/epoch - 8ms/step
# Epoch 92/100
# 5/5 - 0s - loss: 0.4501 - accuracy: 0.8049 - val_loss: 0.4197 - val_accuracy: 0.8182 - 42ms/epoch - 8ms/step
# Epoch 93/100
# 5/5 - 0s - loss: 0.4405 - accuracy: 0.8172 - val_loss: 0.4169 - val_accuracy: 0.8252 - 37ms/epoch - 7ms/step
# Epoch 94/100
# 5/5 - 0s - loss: 0.4532 - accuracy: 0.8155 - val_loss: 0.4167 - val_accuracy: 0.8322 - 42ms/epoch - 8ms/step
# Epoch 95/100
# 5/5 - 0s - loss: 0.4477 - accuracy: 0.8084 - val_loss: 0.4178 - val_accuracy: 0.8322 - 40ms/epoch - 8ms/step
# Epoch 96/100
# 5/5 - 0s - loss: 0.4460 - accuracy: 0.7821 - val_loss: 0.4099 - val_accuracy: 0.8252 - 44ms/epoch - 9ms/step
# Epoch 97/100
# 5/5 - 0s - loss: 0.4410 - accuracy: 0.8243 - val_loss: 0.4128 - val_accuracy: 0.8182 - 41ms/epoch - 8ms/step
# Epoch 98/100
# 5/5 - 0s - loss: 0.4341 - accuracy: 0.8172 - val_loss: 0.4114 - val_accuracy: 0.8322 - 37ms/epoch - 7ms/step
# Epoch 99/100
# 5/5 - 0s - loss: 0.4355 - accuracy: 0.8014 - val_loss: 0.4153 - val_accuracy: 0.8322 - 37ms/epoch - 7ms/step
# Epoch 100/100
# 5/5 - 0s - loss: 0.4334 - accuracy: 0.7979 - val_loss: 0.4101 - val_accuracy: 0.8322 - 38ms/epoch - 8ms/step

# %% [markdown]
# ### Mostrar gráficas de evolución de las pérdidas y la exactitud (*accuracy*)

# %%
#17.- Graficas de pérdidas y exactitud ('accuracy')

# %% [markdown]
# ### Evaluar el modelo

# %%
# 18.- Aplicamos el método evaluate sobre los datos de test
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4985 - accuracy: 0.7765
# [0.4984647035598755, 0.7765362858772278]
